# %% [markdown]
# # NEUR3002 HW2 Test

# %% [markdown]
# ## BY: TA

# %% [markdown]
# **Define the following**

# %% [markdown]
# * temporal
# * rate
# * latency
# * synchronous
# * tuning curve
# * population code

# %% [markdown]
# **Compare and Contrast**

# %% [markdown]
# ![hw2.jpeg](attachment:dd4c0040-1071-4147-845e-884fe146a769.jpeg)
